# %%
from bs4 import BeautifulSoup
import requests

# %%
html_page = requests.get('https://newyork.craigslist.org/search/aap')
soup = BeautifulSoup(html_page.content, "html.parser")

# %%
div = soup.findAll('span', class_='result-price')

# %%
div[0].text
# Out:
# '$3995'

# %%
div2 = soup.findAll('li', {class : })

# %%
div2.
# Out:
# [<p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2019-08-14 08:58" title="Wed 14 Aug 08:58:17 AM">Aug 14</time>
#  <a class="result-title hdrlnk" data-id="6956300521" href="https://newyork.craigslist.org/brk/abo/d/brooklyn-large-duplex-4-br-with-private/6956300521.html">large duplex - 4 br with private back yard</a>
#  <span class="result-meta">
#  <span class="result-price">$3995</span>
#  <span class="housing">
#                      4br -
#                  </span>
#  <span class="result-hood"> (clinton hill)</span>
#  <span class="result-tags">
#  <span class="pictag">pic</span>
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
# ...

# %%
base_url = 'https://newyork.craigslist.org/search/aap'
pagination = base_url + '?s='
