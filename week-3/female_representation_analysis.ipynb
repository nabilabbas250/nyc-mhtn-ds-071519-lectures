# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import sqlite3
import seaborn as sns
import csv

# %%
conn = sqlite3.connect('female_representation_project_1.csv')
c = conn.cursor()

# %%
c.execute("""SELECT * FROM female_representation_project_1.csv""")
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-9-d3d1cb2b5f08> in <module>
# ----> 1 c.execute("""SELECT * FROM female_representation_project_1.csv""")
#
# DatabaseError: file is not a database

# %%
df_va = pd.read_csv('female_representation_project_1.csv')
del df_va['percent_profit']

# %%
df_va.head()
# Out:
#    movie_id   f_rep  vote_average
# 0        11  0.0833           8.2
# 1        12  0.1765           7.8
# 2        13  0.2667           8.4
# 3        14  0.6000           8.0
# 4        15  0.1250           8.1

# %%
for column in df:
    if df[column].isnull().any():
        print('{0} has {1} null values'.format(column, df[column].isnull().sum()))
# Out:
# percent_profit has 184 null values

# %%
df_pp = pd.read_csv('female_representation_project_1.csv')
del df_pp['vote_average']

# %%
df_pp[df_pp['percent_profit'] == 'NaN']
# Out:
# Empty DataFrame
# Columns: [movie_id, f_rep, percent_profit]
# Index: []

# %%
df
# Out:
#      movie_id   f_rep  percent_profit  vote_average
# 0          11  0.0833         7049.07           8.2
# 1          12  0.1765         1000.36           7.8
# 2          13  0.2667         1232.63           8.4
# 3          14  0.6000         2375.31           8.0
# 4          15  0.1250         2764.91           8.1
# 5          16  0.3000          312.75           7.9
# 6          18  0.1176          293.24           7.4
# 7          22  0.4444          467.87           7.7
# 8          24  0.4545          603.16           7.9
# 9          28  0.2000          284.00           8.2
# 10         33  0.2500         1136.84           7.9
# 11         38  0.3000          361.29           8.1
# 12         63  0.2308          572.34           7.5
# 13         69  0.2857          665.85           7.4
# 14         70  0.2308          722.55           7.9
# 15         71  0.4000         2185.61           7.6
# 16         73  0.2857          119.38           8.4
# 17         77  0.1667          441.37           8.2
# 18         78  0.2222          117.39           7.9
# 19         85  0.0714         2166.26           7.9
# 20         89  0.0667          987.86           7.8
# 21         93  0.2857             NaN           7.9
# 22         98  0.0833          444.31           8.1
# 23        100  0.1111         2100.46           8.1
# 24        103  0.2857         2174.04           8.2
# 25        105  0.2857         2005.84           8.2
# 26        106  0.1250          655.12           7.4
# 27        111  0.1667          263.54           8.1
# 28        115  0.1429          307.93           7.9
# 29        117  0.1667          305.08           7.8
# ..        ...     ...             ...           ...
# 674    419478  0.6667             NaN           7.7
# 675    420814  0.2000          132.19           7.4
# 676    424694  0.1000         1719.28           8.1
# 677    429617  0.2353          613.78           7.8
# 678    432517  0.2222             NaN           8.4
# 679    433498  0.1667             NaN           7.4
# 680    435129  1.0000             NaN           7.9
# 681    437586  0.6667         2671.80           7.4
# 682    449176  0.4444          357.93           8.2
# 683    450945  0.2857             NaN           7.6
# 684    451480  0.4286             NaN           7.7
# 685    451915  0.5556             NaN           7.6
# 686    452522  0.4667             NaN           8.3
# 687    466272  0.3333           17.74           7.4
# 688    466282  0.5714             NaN           7.9
# 689    467062  0.2000             NaN           7.5
# 690    469019  0.1818             NaN           7.6
# 691    470044  0.5000          126.80           8.2
# 692    470878  0.6667             NaN           7.6
# 693    472424  0.5000             NaN           7.7
# 694    487670  0.2143             NaN           7.4
# 695    489925  0.5000          676.99           7.4
# 696    489930  0.3333             NaN           7.6
# 697    489999  0.6667         6626.52           7.6
# 698    490132  0.3750         1390.00           8.3
# 699    491418  0.5000           30.63           7.6
# 700    504608  0.3750          418.31           7.6
# 701    527641  0.6667             NaN           8.2
# 702    568332  1.0000             NaN           8.1
# 703    593691  0.4286             NaN           8.6
#
# [704 rows x 4 columns]

# %%
df_pp
# Out:
#      movie_id   f_rep  percent_profit
# 0          11  0.0833         7049.07
# 1          12  0.1765         1000.36
# 2          13  0.2667         1232.63
# 3          14  0.6000         2375.31
# 4          15  0.1250         2764.91
# 5          16  0.3000          312.75
# 6          18  0.1176          293.24
# 7          22  0.4444          467.87
# 8          24  0.4545          603.16
# 9          28  0.2000          284.00
# 10         33  0.2500         1136.84
# 11         38  0.3000          361.29
# 12         63  0.2308          572.34
# 13         69  0.2857          665.85
# 14         70  0.2308          722.55
# 15         71  0.4000         2185.61
# 16         73  0.2857          119.38
# 17         77  0.1667          441.37
# 18         78  0.2222          117.39
# 19         85  0.0714         2166.26
# 20         89  0.0667          987.86
# 21         93  0.2857             NaN
# 22         98  0.0833          444.31
# 23        100  0.1111         2100.46
# 24        103  0.2857         2174.04
# 25        105  0.2857         2005.84
# 26        106  0.1250          655.12
# 27        111  0.1667          263.54
# 28        115  0.1429          307.93
# 29        117  0.1667          305.08
# ..        ...     ...             ...
# 674    419478  0.6667             NaN
# 675    420814  0.2000          132.19
# 676    424694  0.1000         1719.28
# 677    429617  0.2353          613.78
# 678    432517  0.2222             NaN
# 679    433498  0.1667             NaN
# 680    435129  1.0000             NaN
# 681    437586  0.6667         2671.80
# 682    449176  0.4444          357.93
# 683    450945  0.2857             NaN
# 684    451480  0.4286             NaN
# 685    451915  0.5556             NaN
# 686    452522  0.4667             NaN
# 687    466272  0.3333           17.74
# 688    466282  0.5714             NaN
# 689    467062  0.2000             NaN
# 690    469019  0.1818             NaN
# 691    470044  0.5000          126.80
# 692    470878  0.6667             NaN
# 693    472424  0.5000             NaN
# 694    487670  0.2143             NaN
# 695    489925  0.5000          676.99
# 696    489930  0.3333             NaN
# 697    489999  0.6667         6626.52
# 698    490132  0.3750         1390.00
# 699    491418  0.5000           30.63
# 700    504608  0.3750          418.31
# 701    527641  0.6667             NaN
# 702    568332  1.0000             NaN
# 703    593691  0.4286             NaN
#
# [704 rows x 3 columns]

# %%
df_pp.head()
# Out:
# 704

# %%
df_pp2 = df_pp.dropna(how='any',axis=0) 
len(df_pp2)
# Out:
# 520

# %%
del df_pp2[df['percent_profit'] > 50000]
# Out:
# 520

# %%
#plt.scatter(x, y, label = "fea")
plt.scatter(df_pp2.percent_profit, df_pp2.f_rep)
plt.figure(figsize = (10,6))

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('female_representation_project_1.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
#     for column in plots:
#         x.append(int(column['f_rep']))
#         y.append(int(column['percent_profit']))

# plt.plot(x,y, label='Loaded from file!')
# plt.xlabel('x')
# plt.ylabel('y')
# plt.title('Interesting Graph\nCheck it out')
# plt.legend()
# plt.show()

# %%
df_pp5 = df_pp2[df_pp2['percent_profit'] < 5000]
len(df_pp5)
# Out:
# 507

# %%
pp_list = []
for value in df_pp5['percent_profit']:
    pp_list.append(value)
len(pp_list)
# Out:
# 507

# %%
reps = []
for value in df_pp5['f_rep']:
    reps.append(value)
print(len(reps))
# Out:
# 507

# %%
va_list = []
for value in df['vote_average']:
    va_list.append(value)
len(va_list)
# Out:
# 704

# %%
reps_va = []
for value in df['f_rep']:
    reps_va.append(value)
print(len(reps_va))
# Out:
# 704

# %%
reps # list of female_cast_rations
pp_list #profit_percent
plt.scatter(grades_range, girls_grades, color='r')
# plt.scatter(grades_range, boys_grades, color='g')
plt.xlabel('Percentage of Actresses in Cast')
plt.ylabel('Profit Percent')
plt.show()

# %%
plt.scatter(reps, pp_list, color='r')
plt.xlabel('Ratio Actresses in Cast')
plt.ylabel('Profit Percent')
plt.title('Female Representation Ratio vs. Profitability', fontsize = 18)
plt.show()

# %%
plt.scatter(reps_va, va_list, color='r')
plt.xlabel('Ratio of Actresses in Cast')
plt.ylabel('Movie Rating')
plt.title('Female Representation Ratio vs. Movie Ratings', fontsize = 18)
plt.show()

# %%
max(pp_list)
# Out:
# 121915200.0
